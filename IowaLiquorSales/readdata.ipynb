# %% [markdown]
# ### Dataset: Iowa Liquor Sales (Sales & Distribution)
# https://data.iowa.gov/Sales-Distribution/Iowa-Liquor-Sales/m3tr-qhgy

# %%
import pandas as pd
import numpy as np

# %%
import pandas as pd
line = 0
chksz = 1000000
for chunk in pd.read_csv("Data/Iowa_Liquor_Sales.csv",chunksize = chksz):
    line += chunk.shape[0]

# %%
line
# Out:
# 21190664

# %%
# last 1000 rows
df = pd.read_csv("Data/Iowa_Liquor_Sales.csv", skiprows = line - 1000)
df
# Out:
#      INV-36261100005  04/30/2021  4972  \
# 0    INV-36221400017  04/29/2021  2626
# 1    INV-36256300033  04/30/2021  4180
# 2    INV-36222000030  04/29/2021  6057
# 3    INV-36231400051  04/29/2021  2536
# 4    INV-36246700001  04/30/2021  3944
# ..               ...         ...   ...
# 995  INV-36238600003  04/30/2021  5561
# 996  INV-36272500021  04/30/2021  2562
# 997  INV-36238300002  04/30/2021  4023
# 998  INV-36221700045  04/29/2021  2248
# 999  INV-36232000007  04/29/2021  4617
#
#                    Quillins Quality Foods Monona        808 S Main St  \
# 0            Hy-Vee Drugstore / University / DSM  4100 University Ave
# 1    Smokin' Joe's #10 Tobacco and Liquor Outlet          480 7th Ave
# 2                    Kum & Go #0731 / Des Moines  3104 University Ave
# 3                         HY-VEE / PLEASANT HILL     4815 Maple Drive
# 4                      Sam's Club 4973 / Dubuque       4400 Asbury Rd
# ...
